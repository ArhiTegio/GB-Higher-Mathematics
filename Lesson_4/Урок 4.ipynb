# %%
import matplotlib.pyplot as plt
import numpy as np
from pylab import *
from mpl_toolkits.mplot3d import Axes3D
import math


fig, ax_f = plt.subplots()

x = np.linspace(100, 500, 800)
a = 0.015
y = sin(a * x)

n = 418.878667 + x * 0
ax_f.plot(n, y)
n2 = 209.4395 + x * 0
ax_f.plot(n2, y)
ax_f.plot(x, y)
ax_f.set_xlim(100, 500)
ax_f.set_ylim(-0.01, 0.02)
ax_f.set_title('Урок4. Задание 4. - Графический метод.')

plt.show()
